# %%
# prompt: load my google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: i once connect to my google drive then create a df using xlsx file in my google drive

import pandas as pd

# Assuming your xlsx file is located at '/content/drive/MyDrive/your_file.xlsx'
# Replace 'your_file.xlsx' with the actual name and path of your file
file_path_2018 = '/content/drive/MyDrive/KULIAH/smt-5/datamining/assignment-4/padi2018-2020.xlsx'
file_path_2021 = '/content/drive/MyDrive/KULIAH/smt-5/datamining/assignment-4/padi2021-2023.xlsx'

# %%
# prompt: create 2 df using these 2 defined excel path before

df_2018 = pd.read_excel(file_path_2018)
df_2021 = pd.read_excel(file_path_2021)

# %%
# prompt: show top 10 rows data from these two df

print(df_2018.head(10))
# print(df_2021.head(10))
# Out:
#          Unnamed: 0                                         Unnamed: 1  \
# 0               NaN  Luas Panen, Produksi, dan Produktivitas Padi M...
# 1               NaN                                    Luas Panen (ha)
# 2               NaN                                               2018
# 3              ACEH                                          329515.78
# 4    SUMATERA UTARA                                          408176.45
# 5    SUMATERA BARAT                                          313050.82
# 6              RIAU                                           71448.08
# 7             JAMBI                                           86202.68
# 8  SUMATERA SELATAN                                          581574.61
# 9          BENGKULU                                           65891.16
#
#   Unnamed: 2 Unnamed: 3             Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN                    NaN        NaN        NaN
# ...

# %%
# prompt: delete first row from df_2018 and df_2021

df_2018 = df_2018.iloc[2:]
df_2021 = df_2021.iloc[2:]

df_2018.head(10)
# Out:
#               Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2                    NaN       2018       2019       2020       2018
# 3                   ACEH  329515.78  310012.46  317869.41      56.49
# 4         SUMATERA UTARA  408176.45  413141.24  388591.22      51.65
# 5         SUMATERA BARAT  313050.82  311671.23  295664.47      47.37
# 6                   RIAU   71448.08   63142.04   64733.13      37.28
# 7                  JAMBI   86202.68   69536.06   84772.93      44.44
# 8       SUMATERA SELATAN  581574.61  539316.52  551320.76      51.48
# 9               BENGKULU   65891.16   64406.86   64137.28      43.83
# 10               LAMPUNG  511940.93  464103.42  545149.05      48.61
# 11  KEP. BANGKA BELITUNG   17233.59   17087.81   17840.55      26.53
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 2        2019       2020        2018        2019        2020
# 3        55.3      55.28   1861567.1   1714437.6  1757313.07
# ...

# %%
df_2021.head(10)
# Out:
#               Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 2                    NaN       2021       2022     2023.00       2021
# 3                   ACEH  297058.38   271750.2   254287.38      55.03
# 4         SUMATERA UTARA     385405   411462.1   406109.49         52
# 5         SUMATERA BARAT  272391.95   271883.1   300564.77      48.36
# 6                   RIAU   53062.35   51054.04    51914.14      40.98
# 7                  JAMBI   64412.26   60539.59    61236.64      46.29
# 8       SUMATERA SELATAN  496241.65   513378.2   504143.03      51.44
# 9               BENGKULU   55704.69   57151.84    57877.18      48.67
# 10               LAMPUNG  489573.23   518256.1   530108.09      50.77
# 11  KEP. BANGKA BELITUNG   18278.27    15107.8    15284.56      38.57
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9
# 2        2022     2023.00        2021       2022     2023.00
# 3       55.55       55.22   1634639.6    1509456  1404234.82
# ...

# %%
# prompt: capture df_2018 value from column 6th to 8th

df_2018_subset = df_2018.iloc[:, 7:10]
df_2018_subset.head(5)
# Out:
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 2        2018        2019        2020
# 3   1861567.1   1714437.6  1757313.07
# 4  2108284.72  2078901.59  2040500.19
# 5  1483076.48  1482996.01  1387269.29
# 6   266375.53   230873.97   243685.04

# %%
df_2021_subset = df_2021.iloc[:, 7:10]
df_2021_subset.head(5)
# Out:
#    Unnamed: 7 Unnamed: 8  Unnamed: 9
# 2        2021       2022     2023.00
# 3   1634639.6    1509456  1404234.82
# 4  2004142.51    2088584  2087474.15
# 5  1317209.38    1373532  1482468.79
# 6   217458.87   213557.2   205972.55

# %%
# prompt: delete first row and reset index df_2018_subset from 0, and rename df_2018_subset column with '2018', '2019', and '2020'

df_2018_subset = df_2018_subset.iloc[1:]
df_2018_subset = df_2018_subset.reset_index(drop=True)
df_2018_subset = df_2018_subset.rename(columns={
    df_2018_subset.columns[0]: '2018',
    df_2018_subset.columns[1]: '2019',
    df_2018_subset.columns[2]: '2020'
})
df_2018_subset.head(5)
# Out:
#          2018        2019        2020
# 0   1861567.1   1714437.6  1757313.07
# 1  2108284.72  2078901.59  2040500.19
# 2  1483076.48  1482996.01  1387269.29
# 3   266375.53   230873.97   243685.04
# 4   383045.74   309932.68   386413.49

# %%
df_2021_subset = df_2021_subset.iloc[1:]
df_2021_subset = df_2021_subset.reset_index(drop=True)
df_2021_subset = df_2021_subset.rename(columns={
    df_2021_subset.columns[0]: '2021',
    df_2021_subset.columns[1]: '2022',
    df_2021_subset.columns[2]: '2023'
})
df_2021_subset.head(5)
# Out:
#          2021      2022        2023
# 0   1634639.6   1509456  1404234.82
# 1  2004142.51   2088584  2087474.15
# 2  1317209.38   1373532  1482468.79
# 3   217458.87  213557.2   205972.55
# 4   298149.25  277743.8   275941.45

# %%
rows = 12
df_2018_subset = df_2018_subset.iloc[rows]
df_2021_subset = df_2021_subset.iloc[rows]

# %%
df_2018_subset
# Out:
# 2018    10499588.23
# 2019     9655653.98
# 2020     9489164.62
# Name: 12, dtype: object

# %%
df_2021_subset
# Out:
# 2021    9618656.81
# 2022       9356445
# 2023    9084107.53
# Name: 12, dtype: object

# %%
df_2018_subset.shape
# Out:
# (3,)

# %%
Y_2018 = [2018, 2019, 2020]
X_2018 = []

Y_2020 = [2020, 2021, 2022]
X_2021 = []

for i in range(df_2018_subset.shape[0]):
    X_2018.append(df_2018_subset.iloc[i])

for i in range(df_2021_subset.shape[0]):
    X_2021.append(df_2021_subset.iloc[i])

print(X_2018)
print(X_2021)
# Out:
# [10499588.23, 9655653.98, 9489164.62]
# [9618656.81, 9356445, 9084107.53]

# %%
from re import X
Y_append = []
X_append = []
for y2018 in Y_2018:
    Y_append.append(y2018)

for y2021 in Y_2020:
    Y_append.append(y2021)

for x2018 in X_2018:
    X_append.append(x2018)

for x2021 in X_2021:
    X_append.append(x2021)

print(X_append)
print(Y_append)
# Out:
# [10499588.23, 9655653.98, 9489164.62, 9618656.81, 9356445, 9084107.53]
# [2018, 2019, 2020, 2020, 2021, 2022]

# %%
data = {'X': X_append, 'Y': Y_append}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)
